# %%
#Currect working directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\Artist Areej'

# %%
import pandas as pd

# %%
#load the Exel file which has extension of .xlsx
data = pd.read_excel("loans_open_date_2022_06 (1).xlsx")

# %%
data.head()
# Out:
#                               المدينة التصنيف         االمنتج قطاع_العميل  \
# 0     بنك التنمية الإجتماعية بالإحساء     نقل  قرض سيارة أجرة    قطاع خاص
# 1  بنك التنمية الإجتماعية فرع المجمعة   مشروع      قرض التميز    قطاع خاص
# 2   بنك التنمية الإجتماعية فرع الرياض   مشروع    قرض مشروع حل    قطاع خاص
# 3   بنك التنمية الإجتماعية فرع الرياض   مشروع      قرض التميز    قطاع خاص
# 4      بنك التنمية الإجتماعية فرع جدة   مشروع      قرض التميز    قطاع خاص
#
#    مبلغ_التمويل قيمة_القسط تاريخ_الصرف جنس_العميل عمر_العميل  \
# 0       78334.0    >= 1000     2022-06        ذكر      >= 40
# 1     2877000.0    >= 1000     2022-03       انثى      >= 30
# 2      281000.0    >= 1000     2022-03       انثى      >= 30
# 3     1700000.0        NaN     2022-04        ذكر      >= 40
# 4     2218980.0    >= 1000     2022-01        ذكر      >= 30
#
#   ألحاله_الإجتماعية إحتياجات_خاصة عدد_أفراد_الأسره  زود_الإدخاري  القيمة
# 0             متزوج          سليم        غير معروف           0.0     0.0
# ...

# %%
data.tail()
# Out:
#                                      المدينة  التصنيف              االمنتج  \
# 82191  بنك التنمية الإجتماعية فرع حفر الباطن  إجتماعي             قرض زواج
# 82192       بنك التنمية الإجتماعية فرع نجران  إجتماعي             قرض أسرة
# 82193    بنك التنمية الإجتماعية فرع الدوادمي       حر  قرض العمل الحر نقدي
# 82194        بنك التنمية الإجتماعية فرع تبوك       حر  قرض العمل الحر نقدي
# 82195       بنك التنمية الإجتماعية فرع جازان  إجتماعي             قرض أسرة
#
#       قطاع_العميل  مبلغ_التمويل قيمة_القسط تاريخ_الصرف جنس_العميل عمر_العميل  \
# 82191    قطاع خاص       42000.0     < 1000     2022-06        ذكر       < 30
# 82192  قطاع حكومي       60000.0    >= 1000     2022-06        ذكر      >= 30
# 82193    قطاع خاص       44000.0    >= 1000     2022-05        ذكر      >= 30
# 82194  قطاع حكومي       20000.0     < 1000     2022-06        ذكر      >= 30
# 82195  قطاع حكومي       60000.0    >= 1000     2022-06        ذكر      >= 40
#
# ...

# %%
print (data.isnull().sum())
# Out:
# المدينة                0
# التصنيف                0
# االمنتج                0
# قطاع_العميل            0
# مبلغ_التمويل           0
# قيمة_القسط           196
# تاريخ_الصرف            0
# جنس_العميل             0
# عمر_العميل             0
# ألحاله_الإجتماعية    106
# إحتياجات_خاصة          0
# عدد_أفراد_الأسره       0
# زود_الإدخاري           0
# القيمة                 0
# dtype: int64

# %%
data.isnull().sum(axis=0)
# Out:
# المدينة                0
# التصنيف                0
# االمنتج                0
# قطاع_العميل            0
# مبلغ_التمويل           0
# قيمة_القسط           196
# تاريخ_الصرف            0
# جنس_العميل             0
# عمر_العميل             0
# ألحاله_الإجتماعية    106
# إحتياجات_خاصة          0
# عدد_أفراد_الأسره       0
# زود_الإدخاري           0
# القيمة                 0
# dtype: int64

# %%
data.shape
# Out:
# (82196, 14)

# %%
(data.isnull().sum(axis = 0) / data.shape[0]) * 100
# Out:
# المدينة              0.000000
# التصنيف              0.000000
# االمنتج              0.000000
# قطاع_العميل          0.000000
# مبلغ_التمويل         0.000000
# قيمة_القسط           0.238454
# تاريخ_الصرف          0.000000
# جنس_العميل           0.000000
# عمر_العميل           0.000000
# ألحاله_الإجتماعية    0.128960
# إحتياجات_خاصة        0.000000
# عدد_أفراد_الأسره     0.000000
# زود_الإدخاري         0.000000
# القيمة               0.000000
# dtype: float64

# %%
data.dropna()
# Out:
#                                      المدينة  التصنيف              االمنتج  \
# 0            بنك التنمية الإجتماعية بالإحساء      نقل       قرض سيارة أجرة
# 1         بنك التنمية الإجتماعية فرع المجمعة    مشروع           قرض التميز
# 2          بنك التنمية الإجتماعية فرع الرياض    مشروع         قرض مشروع حل
# 3          بنك التنمية الإجتماعية فرع الرياض    مشروع           قرض التميز
# 4             بنك التنمية الإجتماعية فرع جدة    مشروع           قرض التميز
# ...                                      ...      ...                  ...
# 82191  بنك التنمية الإجتماعية فرع حفر الباطن  إجتماعي             قرض زواج
# 82192       بنك التنمية الإجتماعية فرع نجران  إجتماعي             قرض أسرة
# 82193    بنك التنمية الإجتماعية فرع الدوادمي       حر  قرض العمل الحر نقدي
# 82194        بنك التنمية الإجتماعية فرع تبوك       حر  قرض العمل الحر نقدي
# 82195       بنك التنمية الإجتماعية فرع جازان  إجتماعي             قرض أسرة
#
# ...

# %%
data
# Out:
#                                      المدينة  التصنيف              االمنتج  \
# 0            بنك التنمية الإجتماعية بالإحساء      نقل       قرض سيارة أجرة
# 1         بنك التنمية الإجتماعية فرع المجمعة    مشروع           قرض التميز
# 2          بنك التنمية الإجتماعية فرع الرياض    مشروع         قرض مشروع حل
# 3          بنك التنمية الإجتماعية فرع الرياض    مشروع           قرض التميز
# 4             بنك التنمية الإجتماعية فرع جدة    مشروع           قرض التميز
# ...                                      ...      ...                  ...
# 82191  بنك التنمية الإجتماعية فرع حفر الباطن  إجتماعي             قرض زواج
# 82192       بنك التنمية الإجتماعية فرع نجران  إجتماعي             قرض أسرة
# 82193    بنك التنمية الإجتماعية فرع الدوادمي       حر  قرض العمل الحر نقدي
# 82194        بنك التنمية الإجتماعية فرع تبوك       حر  قرض العمل الحر نقدي
# 82195       بنك التنمية الإجتماعية فرع جازان  إجتماعي             قرض أسرة
#
# ...

# %%
#drop(labels, axis, index, columns, level, inplace, errors)
data.drop(labels=['مبلغ_التمويل'] ,axis=1)
# Out:
#                                      المدينة  التصنيف              االمنتج  \
# 0            بنك التنمية الإجتماعية بالإحساء      نقل       قرض سيارة أجرة
# 1         بنك التنمية الإجتماعية فرع المجمعة    مشروع           قرض التميز
# 2          بنك التنمية الإجتماعية فرع الرياض    مشروع         قرض مشروع حل
# 3          بنك التنمية الإجتماعية فرع الرياض    مشروع           قرض التميز
# 4             بنك التنمية الإجتماعية فرع جدة    مشروع           قرض التميز
# ...                                      ...      ...                  ...
# 82191  بنك التنمية الإجتماعية فرع حفر الباطن  إجتماعي             قرض زواج
# 82192       بنك التنمية الإجتماعية فرع نجران  إجتماعي             قرض أسرة
# 82193    بنك التنمية الإجتماعية فرع الدوادمي       حر  قرض العمل الحر نقدي
# 82194        بنك التنمية الإجتماعية فرع تبوك       حر  قرض العمل الحر نقدي
# 82195       بنك التنمية الإجتماعية فرع جازان  إجتماعي             قرض أسرة
#
#       قطاع_العميل قيمة_القسط تاريخ_الصرف جنس_العميل عمر_العميل  \
# ...
